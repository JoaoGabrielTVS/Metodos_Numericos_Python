# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
#questao 1
b =  3
a = 1

def f(x):
    return x**3 - 3
def funcao():
    i=0
    x = 0
    global a,b
    ai =  a
    bi = b
    if (np.sign(f(a)) * np.sign(f(b))) != -1:
        return 0
    elif (np.sign(f(a)) * np.sign(f(b))) == -1:
        while(i < 1000):
            x = (ai + bi) / 2
            if(f(x) == 0):
                return x
            else:
               if np.sign(f(ai))*np.sign(f(x)) == -1:
                   bi = x
               else:
                   ai = x
            i = i+1
    return x



funcao()
# Out:
# 1.4422495703074083

# %%
#questao 2
#a)

a = np.array([])
x = np.arange(1,51,1)
for i in range(-25,25):
   a = np.concatenate((a, np.array([-0.5*i**2+2.5*i+4.5])))

plt.plot(x,a)
plt.show()
#b)
raiz1 = (-2.5 + np.sqrt(2.5**2 - 4*(-0.5)*4.5))/(2*(-0.5))

print(raiz1)

raiz2 = (-2.5 - np.sqrt(2.5**2 - 4*(-0.5)*4.5))/(2*(-0.5))
print(raiz2)

#c)
def Erro_Relativo(a,b):
    return (np.abs((a-b)) / np.abs(a))

a = 5
b = 10
def f(x):
      return -0.5*x**2+2.5*x+4.5



def funcao():#calcula bissação
    x_anterior = 0
    i=0
    x = 0
    global a,b
    ai =  a
    bi = b
    if (np.sign(f(a)) * np.sign(f(b))) != -1:
        return 0
    elif (np.sign(f(a)) * np.sign(f(b))) == -1:
        while(i <  3):
            x = (ai + bi) / 2
            print(x)
            print("Erro quanto Raiz Real(%):",Erro_Relativo(x,raiz2)*100, "Erro Relativo quanto cada iteração:(%)",Erro_Relativo(x,x_anterior)*100)
            if(f(x) == 0):
                return x
            else:
               if np.sign(f(ai))*np.sign(f(x)) == -1:
                   bi = x
               else:
                   ai = x
            x_anterior = x
            i = i+1
    return x


funcao()
# Out:
# -1.405124837953327
# 6.405124837953327
# 7.5
# Erro quanto Raiz Real(%): 14.598335493955641 Erro Relativo quanto cada iteração:(%) 100.0
# 6.25
# Erro quanto Raiz Real(%): 2.481997407253232 Erro Relativo quanto cada iteração:(%) 20.0
# 6.875
# Erro quanto Raiz Real(%): 6.834547811587971 Erro Relativo quanto cada iteração:(%) 9.090909090909092
# 6.875

# %%
#3)
#3) Questao


x_cal = np.array([])
y_cal  = np.array([])


raiz2 = 0.92
def Erro_Relativo(a,b):
    return (np.abs((a-b)) / np.abs(a))

a = 0.5
b = 1
def f(x):
      return -x**3 + np.sin(x)


def funcao():#calcula bissação
    x_anterior = 0
    i=0
    x = 0.1
    global a,b,y_cal , x_cal
    ai =  a
    bi = b
    print(np.sign(f(a)) * np.sign(f(b)))
    if (np.sign(f(a)) * np.sign(f(b))) != -1:
        return 0
    if (np.sign(f(a)) * np.sign(f(b))) == -1:
        while(Erro_Relativo(x,raiz2)*100 > 2):
            x = (ai + bi) / 2
            y_cal = np.concatenate((y_cal,np.array([x])))
            x_cal = np.concatenate((x_cal,np.array([i])))
            print(x)
            if(f(x) == 0):
                return x
            else:
               if np.sign(f(ai))*np.sign(f(x)) == -1:
                   bi = x
               else:
                   ai = x
            x_anterior = x
            i = i+0.2
    return x
funcao()
plt.plot(x_cal,y_cal)
plt.show()
# Out:
# -1.0
# 0.75
# 0.875
# 0.9375
